# %% [markdown]
# **Nádia Winy - ADS 4M ED2 - 021**

# %% [markdown]
# **Quadro de medalhas dos campões sul-americano de Vôlei Feminino**
# [Link da noticia](https://olympics.com/pt/noticias/sul-americano-volei-feminino-titulos-brasil-lista-completa)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Series**

# %%
pais = ['Brasil', 'Peru', 'Argentina', 'Colômbia', 'Uruguai', 'Paraguai', 'Venezuela']

# %%
total = [34, 32, 20, 6, 6, 2, 5]

# %%
serie1 = pd.Series(total, index= pais)
serie1
# Out:
# Brasil       34
# Peru         32
# Argentina    20
# Colômbia      6
# Uruguai       6
# Paraguai      2
# Venezuela     5
# dtype: int64

# %%
serie1.plot()
# Out:
# <Axes: >

# %%
serie1.plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# **Usando DataFrame**

# %%
sul_amric= {
    'pais': ['Brasil', 'Peru', 'Argentina', 'Colômbia', 'Uruguai', 'Paraguai', 'Venezuela'],
    'ouro': [23, 12, 0, 0, 0, 0, 0],
    'prata': [11, 11, 7, 3, 2, 1, 0],
    'bronze': [0, 9, 13, 3, 4, 1, 5],
    'total': [34, 32, 20, 6, 6, 2, 5]
}

# %%
df = pd.DataFrame(sul_amric)
print (df)
# Out:
#         pais  ouro  prata  bronze  total
# 0     Brasil    23     11       0     34
# 1       Peru    12     11       9     32
# 2  Argentina     0      7      13     20
# 3   Colômbia     0      3       3      6
# 4    Uruguai     0      2       4      6
# 5   Paraguai     0      1       1      2
# 6  Venezuela     0      0       5      5

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# **Explique as conclusões que se pode obter da visualização desse resultado** -
# Que ao longo dos campionatos do Sul-americano de vôlei o Brasil se manteve na liderança ao se referir à quantidade de medalhas, comparado aos outro países sul-americanos.
