# %% [markdown]
# **Utilize as informações sobre empresas ativas e inativas e, com os comandos aprendidos em sala, realize o pré-processamento dos dados.**

# %% [markdown]
# **Nádia Winy - ADS ED2 - 021**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Empresas Ativas**

# %%
EmpAtivas = pd.read_csv('empresasativender.csv', sep= ';')
# Out:
# <ipython-input-3-f8d041392a71>:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   EmpAtivas = pd.read_csv('empresasativender.csv', sep= ';')

# %%
EmpAtivas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315518 entries, 0 to 315517
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   cnpj                     315518 non-null  object
#  1   razao_social             315518 non-null  object
#  2   nome_fantasia            245491 non-null  object
#  3   cod_logradouro           315518 non-null  int64
#  4   nome_logradouro          315518 non-null  object
#  5   numero_residencia        163212 non-null  object
#  6   numero_lote              315518 non-null  object
#  7   cod_bairro               315518 non-null  int64
#  8   nome_bairro              315518 non-null  object
#  9   situacao_empresa         315518 non-null  object
#  10  data_abertura_empresa    315518 non-null  object
#  11  data_encerramento        4 non-null       object
#  12  cod_grupo                315518 non-null  int64
# ...

# %%
df = pd.DataFrame(EmpAtivas)
df.head()
# Out:
#              cnpj                              razao_social nome_fantasia  \
# 0  50669717000107                               ECOSAT LTDA        ECOSAT
# 1  50669717000107                               ECOSAT LTDA        ECOSAT
# 2  50669717000107                               ECOSAT LTDA        ECOSAT
# 3  50669717000107                               ECOSAT LTDA        ECOSAT
# 4  12859211000163  ASSOCIACAO DE MORADORES DE VILA AEROMOCA           NaN
#
#    cod_logradouro   nome_logradouro numero_residencia numero_lote  cod_bairro  \
# 0            9342  Rua Azevedo Cruz               NaN   221               884
# 1            9342  Rua Azevedo Cruz               NaN   221               884
# 2            9342  Rua Azevedo Cruz               NaN   221               884
# 3            9342  Rua Azevedo Cruz               NaN   221               884
# 4           75078       Rua Aiquara               NaN   25                884
#
#   nome_bairro situacao_empresa  ... cod_grupo  \
# ...

# %%
df.isnull()
df.head()
# Out:
#              cnpj                              razao_social nome_fantasia  \
# 0  50669717000107                               ECOSAT LTDA        ECOSAT
# 1  50669717000107                               ECOSAT LTDA        ECOSAT
# 2  50669717000107                               ECOSAT LTDA        ECOSAT
# 3  50669717000107                               ECOSAT LTDA        ECOSAT
# 4  12859211000163  ASSOCIACAO DE MORADORES DE VILA AEROMOCA           NaN
#
#    cod_logradouro   nome_logradouro numero_residencia numero_lote  cod_bairro  \
# 0            9342  Rua Azevedo Cruz               NaN   221               884
# 1            9342  Rua Azevedo Cruz               NaN   221               884
# 2            9342  Rua Azevedo Cruz               NaN   221               884
# 3            9342  Rua Azevedo Cruz               NaN   221               884
# 4           75078       Rua Aiquara               NaN   25                884
#
# ...

# %%
df.isnull().sum()
# Out:
# cnpj                            0
# razao_social                    0
# nome_fantasia               70027
# cod_logradouro                  0
# nome_logradouro                 0
# numero_residencia          152306
# numero_lote                     0
# cod_bairro                      0
# nome_bairro                     0
# situacao_empresa                0
# data_abertura_empresa           0
# data_encerramento          315514
# cod_grupo                       0
# nome_grupo                      0
# cnae                            0
# desc_atividade                  0
# atividade_principal             0
# atividade_vig_sanitaria         0
# atividade_predominante          0
# incomodo                        0
# latitude                    32378
# longitude                   32378
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 602603

# %%
df['nome_fantasia'].fillna('Desconhecido', inplace=True)
df['numero_residencia'].fillna('S/N', inplace=True)
df.head()
# Out:
#              cnpj                              razao_social nome_fantasia  \
# 0  50669717000107                               ECOSAT LTDA        ECOSAT
# 1  50669717000107                               ECOSAT LTDA        ECOSAT
# 2  50669717000107                               ECOSAT LTDA        ECOSAT
# 3  50669717000107                               ECOSAT LTDA        ECOSAT
# 4  12859211000163  ASSOCIACAO DE MORADORES DE VILA AEROMOCA  Desconhecido
#
#    cod_logradouro   nome_logradouro numero_residencia numero_lote  cod_bairro  \
# 0            9342  Rua Azevedo Cruz               S/N   221               884
# 1            9342  Rua Azevedo Cruz               S/N   221               884
# 2            9342  Rua Azevedo Cruz               S/N   221               884
# 3            9342  Rua Azevedo Cruz               S/N   221               884
# 4           75078       Rua Aiquara               S/N   25                884
#
# ...

# %%
df['data_abertura_empresa'] = pd.to_datetime(df['data_abertura_empresa'], errors='coerce')
df['data_encerramento'] = pd.to_datetime(df['data_encerramento'], errors='coerce')
df.head()
# Out:
#                   cnpj                                       razao_social  \
# 0       50669717000107                                        ECOSAT LTDA
# 1       50669717000107                                        ECOSAT LTDA
# 2       50669717000107                                        ECOSAT LTDA
# 3       50669717000107                                        ECOSAT LTDA
# 4       12859211000163           ASSOCIACAO DE MORADORES DE VILA AEROMOCA
# ...                ...                                                ...
# 315513  35788779000136  COLISEU TERCEIRIZACOES E SERVIÇOS DE MANUTENCA...
# 315514  35788779000136  COLISEU TERCEIRIZACOES E SERVIÇOS DE MANUTENCA...
# 315515  35788779000136  COLISEU TERCEIRIZACOES E SERVIÇOS DE MANUTENCA...
# 315516  35788779000136  COLISEU TERCEIRIZACOES E SERVIÇOS DE MANUTENCA...
# 315517  40811846000126                            GRUPO UNIAO COMUNITARIA
#
#                    nome_fantasia  cod_logradouro  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315518 entries, 0 to 315517
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   cnpj                     315518 non-null  object
#  1   razao_social             315518 non-null  object
#  2   nome_fantasia            315518 non-null  object
#  3   cod_logradouro           315518 non-null  int64
#  4   nome_logradouro          315518 non-null  object
#  5   numero_residencia        315518 non-null  object
#  6   numero_lote              315518 non-null  object
#  7   cod_bairro               315518 non-null  int64
#  8   nome_bairro              315518 non-null  object
#  9   situacao_empresa         315518 non-null  object
#  10  data_abertura_empresa    315510 non-null  datetime64[ns]
#  11  data_encerramento        4 non-null       datetime64[ns]
#  12  cod_grupo                315518 non-null  int64
# ...

# %%
df2 = df.copy()

# %%
colunas_desnecessarias = ['latitude', 'longitude']
df3 = df.drop(colunas_desnecessarias , axis=1, inplace=True)
df.head()
# Out:
#              cnpj                              razao_social nome_fantasia  \
# 0  50669717000107                               ECOSAT LTDA        ECOSAT
# 1  50669717000107                               ECOSAT LTDA        ECOSAT
# 2  50669717000107                               ECOSAT LTDA        ECOSAT
# 3  50669717000107                               ECOSAT LTDA        ECOSAT
# 4  12859211000163  ASSOCIACAO DE MORADORES DE VILA AEROMOCA           NaN
#
#    cod_logradouro   nome_logradouro numero_residencia numero_lote  cod_bairro  \
# 0            9342  Rua Azevedo Cruz               NaN   221               884
# 1            9342  Rua Azevedo Cruz               NaN   221               884
# 2            9342  Rua Azevedo Cruz               NaN   221               884
# 3            9342  Rua Azevedo Cruz               NaN   221               884
# 4           75078       Rua Aiquara               NaN   25                884
#
# ...

# %% [markdown]
# **Empresas Inativas**

# %%
EmpInativas = pd.read_csv('empresasinativender.csv', sep= ';')

# %%
EmpInativas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292873 entries, 0 to 292872
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   cnpj                     292873 non-null  object
#  1   razao_social             292873 non-null  object
#  2   nome_fantasia            197402 non-null  object
#  3   cod_logradouro           292873 non-null  int64
#  4   nome_logradouro          292873 non-null  object
#  5   numero_residencia        140630 non-null  object
#  6   numero_lote              292873 non-null  object
#  7   cod_bairro               292873 non-null  int64
#  8   nome_bairro              292873 non-null  object
#  9   situacao_empresa         292873 non-null  object
#  10  data_abertura_empresa    292873 non-null  object
#  11  data_encerramento        78145 non-null   object
#  12  cod_grupo                292873 non-null  int64
# ...

# %%
df1 = pd.DataFrame(EmpInativas)
df1.head()
# Out:
#              cnpj                   razao_social nome_fantasia  \
# 0  03561119000121        ROTENO CONSTRUCOES LTDA           NaN
# 1  03561119000121        ROTENO CONSTRUCOES LTDA           NaN
# 2  03561119000121        ROTENO CONSTRUCOES LTDA           NaN
# 3  00388321000105  CAMADA OLISI CONSTRUCOES LTDA           NaN
# 4  00388321000105  CAMADA OLISI CONSTRUCOES LTDA           NaN
#
#    cod_logradouro       nome_logradouro numero_residencia numero_lote  \
# 0            9342      Rua Azevedo Cruz               NaN   213
# 1            9342      Rua Azevedo Cruz               NaN   213
# 2            9342      Rua Azevedo Cruz               NaN   213
# 3           61620  Rua Tristão da Cunha               NaN   6
# 4           61620  Rua Tristão da Cunha               NaN   6
#
#    cod_bairro nome_bairro situacao_empresa  ... cod_grupo  \
# 0         884       COHAB           INAPTO  ...         1
# 1         884       COHAB           INAPTO  ...         1
# ...

# %%
df1.isnull()
df1.head()
# Out:
#              cnpj                   razao_social nome_fantasia  \
# 0  03561119000121        ROTENO CONSTRUCOES LTDA           NaN
# 1  03561119000121        ROTENO CONSTRUCOES LTDA           NaN
# 2  03561119000121        ROTENO CONSTRUCOES LTDA           NaN
# 3  00388321000105  CAMADA OLISI CONSTRUCOES LTDA           NaN
# 4  00388321000105  CAMADA OLISI CONSTRUCOES LTDA           NaN
#
#    cod_logradouro       nome_logradouro numero_residencia numero_lote  \
# 0            9342      Rua Azevedo Cruz               NaN   213
# 1            9342      Rua Azevedo Cruz               NaN   213
# 2            9342      Rua Azevedo Cruz               NaN   213
# 3           61620  Rua Tristão da Cunha               NaN   6
# 4           61620  Rua Tristão da Cunha               NaN   6
#
#    cod_bairro nome_bairro situacao_empresa  ... cod_grupo  \
# 0         884       COHAB           INAPTO  ...         1
# 1         884       COHAB           INAPTO  ...         1
# ...

# %%
df1.isnull().sum()
# Out:
# cnpj                            0
# razao_social                    0
# nome_fantasia               95471
# cod_logradouro                  0
# nome_logradouro                 0
# numero_residencia          152243
# numero_lote                     0
# cod_bairro                      0
# nome_bairro                     0
# situacao_empresa                0
# data_abertura_empresa           0
# data_encerramento          214728
# cod_grupo                       0
# nome_grupo                      0
# cnae                            0
# desc_atividade                  0
# atividade_principal             0
# atividade_vig_sanitaria         0
# atividade_predominante          0
# incomodo                        0
# latitude                    37123
# longitude                   37123
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 536688

# %%
df1['nome_fantasia'].fillna('Desconhecido', inplace=True)
df1['numero_residencia'].fillna('S/N', inplace=True)
df1.head()
# Out:
#              cnpj                   razao_social nome_fantasia  \
# 0  03561119000121        ROTENO CONSTRUCOES LTDA  Desconhecido
# 1  03561119000121        ROTENO CONSTRUCOES LTDA  Desconhecido
# 2  03561119000121        ROTENO CONSTRUCOES LTDA  Desconhecido
# 3  00388321000105  CAMADA OLISI CONSTRUCOES LTDA  Desconhecido
# 4  00388321000105  CAMADA OLISI CONSTRUCOES LTDA  Desconhecido
#
#    cod_logradouro       nome_logradouro numero_residencia numero_lote  \
# 0            9342      Rua Azevedo Cruz               S/N   213
# 1            9342      Rua Azevedo Cruz               S/N   213
# 2            9342      Rua Azevedo Cruz               S/N   213
# 3           61620  Rua Tristão da Cunha               S/N   6
# 4           61620  Rua Tristão da Cunha               S/N   6
#
#    cod_bairro nome_bairro situacao_empresa  ... cod_grupo  \
# 0         884       COHAB           INAPTO  ...         1
# 1         884       COHAB           INAPTO  ...         1
# ...

# %%
df1['data_abertura_empresa'] = pd.to_datetime(df['data_abertura_empresa'], errors='coerce')
df1['data_encerramento'] = pd.to_datetime(df['data_encerramento'], errors='coerce')
df1.head()
# Out:
#              cnpj                   razao_social nome_fantasia  \
# 0  03561119000121        ROTENO CONSTRUCOES LTDA  Desconhecido
# 1  03561119000121        ROTENO CONSTRUCOES LTDA  Desconhecido
# 2  03561119000121        ROTENO CONSTRUCOES LTDA  Desconhecido
# 3  00388321000105  CAMADA OLISI CONSTRUCOES LTDA  Desconhecido
# 4  00388321000105  CAMADA OLISI CONSTRUCOES LTDA  Desconhecido
#
#    cod_logradouro       nome_logradouro numero_residencia numero_lote  \
# 0            9342      Rua Azevedo Cruz               S/N   213
# 1            9342      Rua Azevedo Cruz               S/N   213
# 2            9342      Rua Azevedo Cruz               S/N   213
# 3           61620  Rua Tristão da Cunha               S/N   6
# 4           61620  Rua Tristão da Cunha               S/N   6
#
#    cod_bairro nome_bairro situacao_empresa  ... cod_grupo  \
# 0         884       COHAB           INAPTO  ...         1
# 1         884       COHAB           INAPTO  ...         1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292873 entries, 0 to 292872
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   cnpj                     292873 non-null  object
#  1   razao_social             292873 non-null  object
#  2   nome_fantasia            292873 non-null  object
#  3   cod_logradouro           292873 non-null  int64
#  4   nome_logradouro          292873 non-null  object
#  5   numero_residencia        292873 non-null  object
#  6   numero_lote              292873 non-null  object
#  7   cod_bairro               292873 non-null  int64
#  8   nome_bairro              292873 non-null  object
#  9   situacao_empresa         292873 non-null  object
#  10  data_abertura_empresa    292865 non-null  datetime64[ns]
#  11  data_encerramento        4 non-null       datetime64[ns]
#  12  cod_grupo                292873 non-null  int64
# ...

# %%
df4 = df1.copy()

# %%
desnec = ['latitude', 'longitude']
df5 = df1.drop(desnec , axis=1, inplace=True)
df1.head()
# Out:
#              cnpj                   razao_social nome_fantasia  \
# 0  03561119000121        ROTENO CONSTRUCOES LTDA  Desconhecido
# 1  03561119000121        ROTENO CONSTRUCOES LTDA  Desconhecido
# 2  03561119000121        ROTENO CONSTRUCOES LTDA  Desconhecido
# 3  00388321000105  CAMADA OLISI CONSTRUCOES LTDA  Desconhecido
# 4  00388321000105  CAMADA OLISI CONSTRUCOES LTDA  Desconhecido
#
#    cod_logradouro       nome_logradouro numero_residencia numero_lote  \
# 0            9342      Rua Azevedo Cruz               S/N   213
# 1            9342      Rua Azevedo Cruz               S/N   213
# 2            9342      Rua Azevedo Cruz               S/N   213
# 3           61620  Rua Tristão da Cunha               S/N   6
# 4           61620  Rua Tristão da Cunha               S/N   6
#
#    cod_bairro nome_bairro situacao_empresa data_abertura_empresa  \
# 0         884       COHAB           INAPTO            2023-05-15
# ...
